# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.19 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5597.6/8062.4 GB disk)

# %%
# !cp -r '/kaggle/input/face-diagnosis/train' /kaggle/working/
# !cp -r '/kaggle/input/face-diagnosis/valid' /kaggle/working/
# !cp -r '/kaggle/input/face-diagnosis/test' /kaggle/working/
# !cp -r '/kaggle/input/face-diagnosis/data.yaml' /kaggle/working

# %%
# %cd /kaggle/working
from IPython.display import FileLink
FileLink('runs/detect/train/weights/best.pt')
# Out:
# /kaggle/working
# /kaggle/working/runs/detect/train/weights/best.pt

# %%
from ultralytics import YOLO
model = YOLO('yolov8m.pt')
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 220MB/s]

# %%
results = model.train(data='/kaggle/working/data.yaml', epochs=100, imgsz=640)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 results = model.train(data='/kaggle/working/data.yaml', epochs=100, imgsz=640)
#
# NameError: name 'model' is not defined
